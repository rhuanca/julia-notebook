# %%
using Plots

# %%
x = -3:0.1:3
f(x) = x^2
y = f.(x)
gr()
# Out:
# Plots.GRBackend()

# %%
plot(x,y,label="line")

# %%
scatter(x,y,label="points")

# %%
plot(x,y,label="line")
scatter!(x,y,label="points")

# %%
x = 1:10; y = rand(10); # These are the plotting data
plot(x,y)

# %%
#using CSV
dt = CSV.read("sample.csv")
# Out:
# 7×2 DataFrames.DataFrame
# │ Row │ deviceid │ temperature │
# ├─────┼──────────┼─────────────┤
# │ 1   │ D1       │ 12          │
# │ 2   │ D2       │ 13          │
# │ 3   │ D3       │ 14          │
# │ 4   │ D4       │ 12          │
# │ 5   │ D5       │ 13          │
# │ 6   │ D6       │ 15          │
# │ 7   │ D7       │ 12          │

# %%
using StatPlots

# %%
@df dt bar(:deviceid, [:temperature ], label="temperature")
